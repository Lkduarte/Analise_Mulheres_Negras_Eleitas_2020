# %%
import pandas as pd
low_memory=False
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
filename = r'C:\Users\luke_\Downloads\consulta_cand_2020\consulta_cand_2020_BRASIL.csv'
df = pd.read_csv(filename, delimiter=';', encoding='Latin1', error_bad_lines=False)

# %%
df.shape
# Out:
# (557634, 63)

# %%
df.info
# Out:
# <bound method DataFrame.info of         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 0       05/12/2020   11:18:48         2020                2
# 1       05/12/2020   11:18:48         2020                2
# 2       05/12/2020   11:18:48         2020                2
# 3       05/12/2020   11:18:48         2020                2
# 4       05/12/2020   11:18:48         2020                2
# ...            ...        ...          ...              ...
# 557629  05/12/2020   11:18:48         2020                2
# 557630  05/12/2020   11:18:48         2020                2
# 557631  05/12/2020   11:18:48         2020                2
# 557632  05/12/2020   11:18:48         2020                2
# 557633  05/12/2020   11:18:48         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 0       ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# ...

# %%
#Amostragem de 10 dados
df.sample(10)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 143185  05/12/2020   11:18:48         2020                2
# 11843   05/12/2020   11:18:48         2020                2
# 231714  05/12/2020   11:18:48         2020                2
# 177303  05/12/2020   11:18:48         2020                2
# 168405  05/12/2020   11:18:48         2020                2
# 188790  05/12/2020   11:18:48         2020                2
# 337196  05/12/2020   11:18:48         2020                2
# 135182  05/12/2020   11:18:48         2020                2
# 348942  05/12/2020   11:18:48         2020                2
# 233400  05/12/2020   11:18:48         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 143185  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# 11843   ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# 231714  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# ...

# %%
#Agrupamento do número de candidatos por gênero em gráfico de barras horizontais
df.groupby('DS_GENERO').size().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='DS_GENERO'>

# %%
#Agrupamento do número de canditados por gênero
df.groupby('DS_GENERO').size().sort_values(ascending=False)
# Out:
# DS_GENERO
# MASCULINO    370552
# FEMININO     187082
# dtype: int64

# %%
#Agrupamento de candidatos por raça em gráfico de barras horizontais
df.groupby('DS_COR_RACA').size().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='DS_COR_RACA'>

# %%
#Agrupamento do número de canditados por raça
df.groupby('DS_COR_RACA').size().sort_values(ascending=False)
# Out:
# DS_COR_RACA
# BRANCA            268080
# PARDA             220308
# PRETA              58703
# SEM INFORMAÇÃO      6365
# INDÍGENA            2216
# AMARELA             1962
# dtype: int64

# %%
#Número de mulheres candidatas
df.query('CD_GENERO == 4')['DS_GENERO'].value_counts()
# Out:
# FEMININO    187082
# Name: DS_GENERO, dtype: int64

# %%
#Número de mulheres candidatas por raça em gráfico de barras verticais
df.query('CD_GENERO == 4')['DS_COR_RACA'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Número de mulheres candidatas por raça
df.query('CD_GENERO == 4')['DS_COR_RACA'].value_counts()
# Out:
# BRANCA            92643
# PARDA             70727
# PRETA             20133
# SEM INFORMAÇÃO     2148
# INDÍGENA            733
# AMARELA             698
# Name: DS_COR_RACA, dtype: int64

# %%
#Número de mulheres negras candidatas
df.query('CD_GENERO == 4 and CD_COR_RACA == 2')['DS_GENERO'].value_counts()
# Out:
# FEMININO    20133
# Name: DS_GENERO, dtype: int64

# %%
#Número de mulheres negras candidadas por cargo em gráfico de barras horizontais
df.query('CD_GENERO == 4 and CD_COR_RACA == 2')['DS_CARGO'].value_counts(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
#Número de mulheres negras candidadas por cargo
df.query('CD_GENERO == 4 and CD_COR_RACA == 2')['DS_CARGO'].value_counts(ascending=False)
# Out:
# VEREADOR         19642
# VICE-PREFEITO      358
# PREFEITO           133
# Name: DS_CARGO, dtype: int64

# %%
#Número de mulheres negras e seus resultados na eleição em gráfico de barras horizontais
df.query('CD_GENERO == 4 and CD_COR_RACA == 2')['DS_SIT_TOT_TURNO'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Número de mulheres negras e seus resultados na eleição
df.query('CD_GENERO == 4 and CD_COR_RACA == 2')['DS_SIT_TOT_TURNO'].value_counts()
# Out:
# SUPLENTE            11794
# NÃO ELEITO           5907
# #NULO#               1903
# ELEITO POR QP         293
# ELEITO POR MÉDIA      176
# ELEITO                 54
# 2º TURNO                6
# Name: DS_SIT_TOT_TURNO, dtype: int64

# %%
#Número de mulheres negras que foram eleitas no primeiro turno na eleição
df.query('CD_GENERO == 4 and CD_COR_RACA == 2 and CD_SIT_TOT_TURNO == 1')['DS_SIT_TOT_TURNO'].value_counts()
# Out:
# ELEITO    54
# Name: DS_SIT_TOT_TURNO, dtype: int64

# %%
#Número de mulheres negras que foram eleitas no primeiro turno na eleição por cargo em gráfico de barras horizontais
df.query('CD_GENERO == 4 and CD_COR_RACA == 2 and CD_SIT_TOT_TURNO == 1')['DS_CARGO'].value_counts(ascending=True).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
#Número de mulheres negras que foram eleitas na eleição por cargo
df.query('CD_GENERO == 4 and CD_COR_RACA == 2 and CD_SIT_TOT_TURNO == 1')['DS_CARGO'].value_counts(ascending=False)
# Out:
# VICE-PREFEITO    44
# PREFEITO         10
# Name: DS_CARGO, dtype: int64
